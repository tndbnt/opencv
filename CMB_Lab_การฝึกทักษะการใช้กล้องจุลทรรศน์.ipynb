# %% [markdown]
# <a href="https://colab.research.google.com/github/tndbnt/opencv/blob/master/CMB_Lab_%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B8%9D%E0%B8%B6%E0%B8%81%E0%B8%97%E0%B8%B1%E0%B8%81%E0%B8%A9%E0%B8%B0%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B9%83%E0%B8%8A%E0%B9%89%E0%B8%81%E0%B8%A5%E0%B9%89%E0%B8%AD%E0%B8%87%E0%B8%88%E0%B8%B8%E0%B8%A5%E0%B8%97%E0%B8%A3%E0%B8%A3%E0%B8%A8%E0%B8%99%E0%B9%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
string1 = "Tanadol Savigun"
string2 = '623020003-0'
string3 = "CMB Lab"
string4 = "Compound Microscope Nikon"
string5 = "ละอองเรณูดอกชบา"

# %%
string1+" "+string2
# Out:
# 'Tanadol Savigun 623020003-0'

# %%
string3+" "+string4+" "+string5
# Out:
# 'CMB Lab Compound Microscope Nikon ละอองเรณูดอกชบา'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import matplotlib.pylab as plt

# %%
image = cv2.imread('https://drive.google.com/file/d/1C1aEuXbrpG4iSsOUyC2JfP5mo2xYV48d/view?usp=sharing')

# %%
input_image=cv2.imread('https://drive.google.com/file/d/1C1aEuXbrpG4iSsOUyC2JfP5mo2xYV48d/view?usp=sharing')

# %%
print(input_image.size)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-8979641b312f> in <module>()
# ----> 1 print(input_image.size)
#
# AttributeError: 'NoneType' object has no attribute 'size'

# %%
print(input_image.shape)
# Out:
# (2048, 2880, 3)

# %%
print(input_image.dtype)
# Out:
# uint8

# %%
plt.imshow(input_image)

# %%
b,g,r=cv2.split(input_image)
plt.imshow(r, cmap='gray')

# %%
merged=cv2.merge([r,g,b])
plt.imshow(merged)

# %%
COLORflags = [flag for flag in dir(cv2) if flag.startswith('COLOR') ]
print(len(COLORflags))
# Out:
# 295

# %%
opencv_merged=cv2.cvtColor(input_image, cv2.COLOR_BGR2RGB)
plt.imshow(opencv_merged)

# %% [markdown]
# ภาพด้านบน คือ ภาพละอองเรณูของดอกชบา ที่กำลังขยาย 40x ซึ่งบันทึกด้วยกล้องถ่ายภาพ Compound microscope ยี่ห้อ Nikon ผ่านโปรแกรม NIS-Elements

# %%
pixel = merged[100,100]
print(pixel)
# Out:
# [206 206 209]

# %%
merged[100,100] = [0,0,0]
pixelnew = merged[100,100]
print(pixelnew)
# Out:
# [0 0 0]

# %%
pollen = merged[500:1750, 1000:1950]
plt.imshow(pollen)

# %% [markdown]
# เมื่อสังเกตภาพขยายของละอองเรณูของดอกชบา จะพบว่าจะมีลักษณะเป็นทรงกลม และมีหนามกระจายอยู่ทั่วผิว
# แต่เนื่องด้วยละอองเรณูนี้มีขนาดใหญ่หรือมีความหนา จึงทำให้ไม่สามารถบันทึกภาพที่สามารถแสดงให้เห็นถึงรายละเอียดของละอองเรณูที่ชัดเจนในทุกระดับของพื้นผิวได้ในภาพเดียว
